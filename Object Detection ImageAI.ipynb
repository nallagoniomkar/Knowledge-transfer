# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import h5py

# %%
print(cv2.__version__)
# Out:
# 4.1.0

# %%
print(tf.__version__)
# Out:
# 1.14.0

# %%
from imageai.Detection import ObjectDetection
import os
# Out:
# Using TensorFlow backend.

# %%
#execution_path = os.getcwd()
#execution_path

# %%
detector = ObjectDetection()
detector

# %%
detector.setModelTypeAsRetinaNet()

# %%
detector.setModelPath( os.path.join('C:\\Users\\nallagoni.omkar\\Documents' , 'resnet50_coco_best_v2.0.1.h5'))

# %%
detector.loadModel()

# %%
custom_objects = detector.CustomObjects(person=True, car=True,motorcycle=True)

# %%
custom_objects = detector.CustomObjects(person=True,dog=True)

# %%
detections = detector.detectCustomObjectsFromImage(input_image=os.path.join('C:\\Users\\nallagoni.omkar\\Desktop', "Image.png"),
                                                  output_image_path=os.path.join('C:\\Users\\nallagoni.omkar\\Desktop', "Image_new1.png"), 
                                                   custom_objects=custom_objects,
                                                    minimum_percentage_probability=65)

# %%
for eachObject in detections:
    print(eachObject["name"] + " : " + eachObject["percentage_probability"] )
    print("--------------------------------")
# Out:
# car : 77.35731601715088
# --------------------------------
# person : 75.89733600616455
# --------------------------------
# car : 99.44254159927368
# --------------------------------
# person : 67.26188063621521
# --------------------------------

# %%
from IPython.display import Image
Image("C:\\Users\\nallagoni.omkar\\Desktop\\Image_new1.png")
